# %%
library(data.table)
library(Biostrings)

# %%
sample = '5dbf3203-ce73-41e4-bf9a-32fc856f73f5'
snv_path = "/srv/home/mlef0011/rawdata/PCAWG_data/TCGA/snv_mnv/5dbf3203-ce73-41e4-bf9a-32fc856f73f5.consensus.20160830.somatic.snv_mnv.vcf.gz"
snv_df = fread(snv_path, data.table=F)
snv_df = snv_df[snv$FILTER == ".",]

# %%
head(snv_df)
dim(snv_df)
# Out:
#   #CHROM POS    ID REF ALT QUAL FILTER
# 1 1      532073 .  G   A   .    REMAPFAIL
# 2 1      545955 .  C   T   .    REMAPFAIL
# 3 1      637010 .  C   T   .    LOWSUPPORT;NORMALPANEL
# 4 1      759549 .  G   A   .    NORMALPANEL;REMAPFAIL
# 5 1      808445 .  C   T   .    LOWSUPPORT;NORMALPANEL
# 6 1      828828 .  A   T   .    .
#   INFO
# 1 Callers=broad,muse;NumCallers=2;VAF=0.1452;repeat_masker=(CA)n;t_alt_count=9;t_ref_count=53
# 2 Callers=broad,muse,sanger;NumCallers=3;VAF=0.3333;t_alt_count=4;t_ref_count=8
# 3 Callers=broad;NumCallers=1;VAF=0.0465;repeat_masker=L1PA14;t_alt_count=4;t_ref_count=82
# 4 Callers=dkfz,muse;NumCallers=2;VAF=0.1646;dbsnp=rs866279505;t_alt_count=13;t_ref_count=66
# 5 Callers=broad;NumCallers=1;VAF=0.0247;t_alt_count=2;t_ref_count=79
# 6 Callers=broad,muse;NumCallers=2;VAF=0.4179;repeat_masker=LTR57-int;t_alt_count=28;t_ref_count=39;signature_N3;Variant_Classification=IGR
# [1] 19625     8

# %%
ref <- readDNAStringSet("/srv/home/mlef0011/rawdata/ref_genome/reference_genome_GRCh37.fa")[1:22]

# %%
names(ref) = paste0("chr", 1:22)

# %%
names(ref)
# Out:
#  [1] "chr1"  "chr2"  "chr3"  "chr4"  "chr5"  "chr6"  "chr7"  "chr8"  "chr9"
# [10] "chr10" "chr11" "chr12" "chr13" "chr14" "chr15" "chr16" "chr17" "chr18"
# [19] "chr19" "chr20" "chr21" "chr22"

# %%
k=31
idx = 1
snv = unlist(as.vector(snv_df[idx,1:2]))
chr = snv[1]
pos = snv[2]
# Out:
# Error in pos - i: non-numeric argument to binary operator
# Traceback:
#
# 1. sapply(0:(k - 1), function(i) {
#  .     start <- pos - i
#  .     end <- start + k - 1
#  .     as.character(subseq(ref[[paste0("chr", chr)]], start, end))
#  . })
# 2. lapply(X = X, FUN = FUN, ...)
# 3. FUN(X[[i]], ...)
# 4. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "non-numeric argument to binary operator", base::quote(pos -
#  .     i))
